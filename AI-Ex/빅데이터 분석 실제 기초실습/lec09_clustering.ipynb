# %% [markdown]
# # Lecture 09 - Clustering
#
# 과목: 산업 빅데이터 분석 실제
#
# - 단원: 09
# - 목적: 강의 PDF 내용을 실습 코드로 재현/확장하기 위한 템플릿
#
# > 참고 PDF: `pdfs/Lecture 09 - Clustering.pdf` (파일명이 다를 수 있음)

# %% [markdown]
# ## 0. 환경 준비
#
# 필요 라이브러리를 불러옵니다. (실습 환경에 따라 설치가 필요할 수 있습니다.)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# 선택: 시각화/ML 라이브러리
# !pip install -q scikit-learn plotly mlxtend

# %% [markdown]
# ## 1. K-Means
#
# KMeans로 군집화하고 시각화합니다.

# %%
from sklearn.cluster import KMeans

X = np.vstack([
    np.random.randn(200, 2) + np.array([0, 0]),
    np.random.randn(200, 2) + np.array([5, 5]),
    np.random.randn(200, 2) + np.array([0, 5]),
])

kmeans = KMeans(n_clusters=3, n_init=10, random_state=42)
labels = kmeans.fit_predict(X)

plt.figure()
plt.scatter(X[:,0], X[:,1], c=labels, s=10)
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=200, marker="X")
plt.title("K-Means Clustering")
plt.show()

# %% [markdown]
# ## 2. Elbow / Silhouette
#
# 적절한 k를 찾는 방법을 실습합니다.

# %%
from sklearn.metrics import silhouette_score

inertias = []
sil = []
Ks = range(2, 9)
for k in Ks:
    km = KMeans(n_clusters=k, n_init=10, random_state=42)
    lab = km.fit_predict(X)
    inertias.append(km.inertia_)
    sil.append(silhouette_score(X, lab))

plt.figure()
plt.plot(list(Ks), inertias, marker="o")
plt.title("Elbow (Inertia)")
plt.xlabel("k"); plt.ylabel("inertia")
plt.show()

plt.figure()
plt.plot(list(Ks), sil, marker="o")
plt.title("Silhouette Score")
plt.xlabel("k"); plt.ylabel("score")
plt.show()

# %% [markdown]
# ## 3. 실습 과제
#
# DBSCAN 등 다른 군집 기법도 시도해보세요.

# %%
# TODO) DBSCAN 적용 후 군집 결과 비교해보기
# from sklearn.cluster import DBSCAN
